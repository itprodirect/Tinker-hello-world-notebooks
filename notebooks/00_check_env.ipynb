# %% [markdown]
# # Notebook 00 — Environment Check
#
# **Objective:** Verify Python, file paths, and SDK installs before calling Tinker.
#
# **Prerequisites:** Python 3.10+, pip, and a valid `TINKER_API_KEY` saved in `.env`.
#
# **Estimated run time:** < 1 minute.
#
# ### How to use this notebook
# 1. Run `python test_env.py` in the repo root to confirm the `.env` file is detected.
# 2. Launch `jupyter lab` (or `jupyter notebook`) from the repo root.
# 3. Open this file and execute the cells from top to bottom. If every printout looks reasonable, continue to `01_tinker_hello_LoRA_world.ipynb`.

# %%
import sys
import os

print("Python version:", sys.version)
print("Working directory:", os.getcwd())
print("Environment files present:", os.listdir(".."))
# Out:
# Python version: 3.12.3 (tags/v3.12.3:f6650f9, Apr  9 2024, 14:05:25) [MSC v.1938 64 bit (AMD64)]
# Working directory: C:\Users\user\Desktop\tinker-hello-world\notebooks
# Environment files present: ['.env', '.env.example', '.gitignore', '.venv', 'notebooks', 'requirements.txt', 'test_env.py']

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print("TINKER_API_KEY Loaded:", bool(os.getenv("TINKER_API_KEY")))
# Out:
# TINKER_API_KEY Loaded: True

# %%
import tinker

print("Tinker SDK version:", tinker.__version__)
# Out:
# Tinker SDK version: 0.3.0

# %%
import transformers

print("Transformers version:", transformers.__version__)
# Out:
# Transformers version: 4.57.1
